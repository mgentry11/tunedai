# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from huggingface_hub import HfApi, login, create_repo

TOKEN = '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'

login(token=TOKEN)

create_repo(repo_id='tunedailabs/causal-reasoning-qwen-7b', repo_type='model', exist_ok=True, token=TOKEN)

api = HfApi()
api.upload_folder(folder_path='/content/drive/MyDrive/rungs_qwen7b_feedback_v2_e1', repo_id='tunedailabs/causal-reasoning-qwen-7b', repo_type='model', token=TOKEN)

print('Done!')
